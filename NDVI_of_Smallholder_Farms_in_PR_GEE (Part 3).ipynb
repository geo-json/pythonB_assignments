# %% [markdown]
# #Investigating The Effect of Hurricane Maria On Smallholder Farms In Puerto Rico
# (Santhi Davedu, Inigo Peng, Vineeth Jason Putti, Yunfan Zhou)
#
# ##Background
# 2017’s Hurricane Maria struck the United States unincorporated territory of Puerto Rico as a category 4 hurricane, causing 2,975 deaths. The archipelago’s agriculture, which was experiencing production improvement during Puerto Rico’s financial crisis, was decimated. Damages to production were estimated to reach approximately 200 million dollars, and 80% of its crop value was devastated. Hurricanes in the Atlantic are likely to become more intense and persistent in the upcoming years due to climate change, which will have profound impacts in island countries and territories, especially in their agricultural systems and food security. Thus, understanding how smallholder farmers are affected by hurricanes is critical for their future adaptation, like what strategies they may use to increase their resiliency in the future.
#
# ##Problem Statement
# We aim to conduct landcover change anaylsis through measurement of measurement of normalized vegetation index. We are interested to see if there is a significant change in landcover change before and after Hurricane Maria. This is part of a larger investigation in combining different data to identify what tools, inputs and management strategies could most effectively contribute to an increase in the resiliance of a given farming operation.
#
# ##Methodology
# This is the second part of the project, where moderate spatial resolution satellite image taken by Sentinel-2 of European Space Agency (ES) is used to analyze smallholder farm data provided by the Environmental Spatial Analysis (ESA) Lab at SEAS. This part of the project is conducted through Google Earth Engine (GEE) Python API. We first conducted some exploratory mapping by creating tri-month false colour composits of Sentinel 2 Level 2A images from June of 2017 to December of 2019. We then proceeded to visualize the NDVI for the composites. To investigate the landcover changes of the individual farms, we first prepared the farm data. The excel coordinates was converted into json file for easy access of geometry (point, coordinates) and properties (farm number, owner of the farm). We overlayed the farm points onto the map and created 1km buffers around all of them. Lastly, we parsed the json file and calculated the NDVI mean and standard deviation of farm.
# ##Python Script

# %%
# Installs geemap package
import subprocess

try:
    import geemap
except ImportError:
    print('geemap package not installed. Installing ...')
    subprocess.check_call(["python", '-m', 'pip', 'install', 'geemap'])

# Checks whether this notebook is running on Google Colab
try:
    import google.colab
    import geemap.eefolium as emap
except:
    import geemap as emap

# Authenticates and initializes Earth Engine
import ee

try:
    ee.Initialize()
except Exception as e:
    ee.Authenticate()
    ee.Initialize()  
import json
import os
import requests
from geemap import geojson_to_ee, ee_to_geojson
from ipyleaflet import GeoJSON
import csv

# %%
# Add Google Map
Map = emap.Map(center=[18,-66], zoom=9)
Map.addLayerControl()
Map
# Out:
# Map(center=[18, -66], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_te…

# %%
#Import farm json file
file_path = 'PR_farms.json'
with open(file_path) as f:
    json_data = json.load(f)

# %%
# Exploratory work with the farm data 
farms = json_data
properties = farms['features'][0]['properties']
geometry = farms['features'][0]['geometry']
farm_data = farms['features']
#Convert json data into Google Earth Engine Features
farm_data_features_list = [ee.Feature(farms['features'][i]['geometry'],farms['features'][i]['properties']) for i in range(len(farm_data))]

# %%
#Append farm points and buffer onto the map
for item in farm_data_features_list:
    Map.addLayer(item, {}, 'Small Holder Farms Research Location Feature')

for item in farm_data_features_list:
    new_geometry = item.buffer(1000)
    Map.addLayer(new_geometry, {'color': 'red'},'buffer')

# %%
# cloud mask function
def maskS2clouds(image):
#     bits 10 and 11 are cloud and cirrus 
    qa = image.select('QA60')
    cloudBitMask = 1 << 10
    cirrusBitMask = 1 << 11
#     both needs to be set to zero - clear condition
    mask = qa.bitwiseAnd(cloudBitMask).eq(0).And(
    qa.bitwiseAnd(cirrusBitMask).eq(0))
#     return the masked and scaled data without the QA bands
    return image.updateMask(mask).divide(10000)\
        .select("B.*")\
        .copyProperties(image, ['system:time_start'])

# %%
#calculating NDVI
def addNDVI(img):
  ndvi = img.normalizedDifference(['B8', 'B4']).rename('ndvi')
  return img.addBands([ndvi])

# %%
# Setting query boundary
PR_polygon = ee.Geometry.Polygon([[[-66.97540283203125, 18.04403274297545],\
                                 [-65.93170166015625, 18.04403274297545],\
                                 [-65.93170166015625, 18.41447273166262],\
                                 [-66.97540283203125, 18.41447273166262],\
                                 [-66.97540283203125, 18.04403274297545]]])

# %%
#Creating composites - composite between March and June had missing pixels due to cloud mask
Start0 = ee.Date('2017-03-28')
End0 = ee.Date('2017-6-30')
img = ee.ImageCollection('COPERNICUS/S2')\
    .filterDate(Start0, End0)\
    .filterBounds(PR_polygon)\
    .filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE', 20))\
    .map(maskS2clouds)
composite0 = img.median()

# %%
Map.addLayer(composite0, {'bands':['B8', 'B4', 'B3'], 'min': 0, 'max':0.3}, 'False IR Composite April - June 2017')

# %%
Start1 = ee.Date('2017-07-01')
End1 = ee.Date('2017-09-30')
img = ee.ImageCollection('COPERNICUS/S2')\
    .filterDate(Start1, End1)\
    .filterBounds(PR_polygon)\
    .filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE', 20))\
    .map(maskS2clouds)
composite1 = img.median()

# %%
Map.addLayer(composite1, {'bands':['B8', 'B4', 'B3'], 'min': 0, 'max':0.3}, 'False IR Composite July - Septeber 2017')

# %%
Start2 = ee.Date('2017-10-01')
End2 = ee.Date('2018-12-31')
img = ee.ImageCollection('COPERNICUS/S2')\
    .filterDate(Start2, End2)\
    .filterBounds(PR_polygon)\
    .filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE', 20))\
    .map(maskS2clouds)
composite2 = img.median()

# %%
Map.addLayer(composite2, {'bands':['B8', 'B4', 'B3'], 'min': 0, 'max':0.3}, 'False IR Composite Oct - Dec 2017')

# %%
Start3 = ee.Date('2018-01-01')
End3 = ee.Date('2018-03-31')
img = ee.ImageCollection('COPERNICUS/S2')\
    .filterDate(Start3, End3)\
    .filterBounds(PR_polygon)\
    .filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE', 20))\
    .map(maskS2clouds)
composite3 = img.median()

# %%
Map.addLayer(composite3, {'bands':['B8', 'B4', 'B3'], 'min': 0, 'max':0.3}, 'False IR Composite Jan - Mar 2018')

# %%
Start4 = ee.Date('2018-04-01')
End4 = ee.Date('2018-06-30')
img = ee.ImageCollection('COPERNICUS/S2')\
    .filterDate(Start4, End4)\
    .filterBounds(PR_polygon)\
    .filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE', 20))\
    .map(maskS2clouds)
composite4 = img.median()

# %%
Map.addLayer(composite4, {'bands':['B8', 'B4', 'B3'], 'min': 0, 'max':0.3}, 'False IR Composite April - June 2018')

# %%
Start5 = ee.Date('2018-07-01')
End5 = ee.Date('2018-09-30')
img = ee.ImageCollection('COPERNICUS/S2')\
    .filterDate(Start5, End5)\
    .filterBounds(PR_polygon)\
    .filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE', 20))\
    .map(maskS2clouds)
composite5 = img.median()

# %%
Map.addLayer(composite5, {'bands':['B8', 'B4', 'B3'], 'min': 0, 'max':0.3}, 'False IR Composite July - Septemer 2018')

# %%
Start6 = ee.Date('2018-10-01')
End6 = ee.Date('2018-12-31')
img = ee.ImageCollection('COPERNICUS/S2')\
    .filterDate(Start6, End6)\
    .filterBounds(PR_polygon)\
    .filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE', 20))\
    .map(maskS2clouds)
composite6 = img.median()

# %%
Map.addLayer(composite6, {'bands':['B8', 'B4', 'B3'], 'min': 0, 'max':0.3}, 'False IR Composite October - December 2018')

# %%
Start7 = ee.Date('2019-1-01')
End7 = ee.Date('2019-3-31')
img = ee.ImageCollection('COPERNICUS/S2')\
    .filterDate(Start7, End7)\
    .filterBounds(PR_polygon)\
    .filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE', 20))\
    .map(maskS2clouds)
composite7 = img.median()

# %%
Map.addLayer(composite7, {'bands':['B8', 'B4', 'B3'], 'min': 0, 'max':0.3}, 'False IR Composite January - March 2019')

# %%
Start8 = ee.Date('2019-4-01')
End8 = ee.Date('2019-6-30')
img = ee.ImageCollection('COPERNICUS/S2')\
    .filterDate(Start8, End8)\
    .filterBounds(PR_polygon)\
    .filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE', 20))\
    .map(maskS2clouds)
composite8 = img.median()

# %%
Map.addLayer(composite8, {'bands':['B8', 'B4', 'B3'], 'min': 0, 'max':0.3}, 'False IR Composite March- June 2019')

# %%
Start9 = ee.Date('2019-07-01')
End9 = ee.Date('2019-09-30')
img = ee.ImageCollection('COPERNICUS/S2')\
    .filterDate(Start9, End9)\
    .filterBounds(PR_polygon)\
    .filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE', 20))\
    .map(maskS2clouds)
composite9 = img.median()

# %%
Map.addLayer(composite9, {'bands':['B8', 'B4', 'B3'], 'min': 0, 'max':0.3}, 'False IR Composite July - September 2019')

# %%
Start10 = ee.Date('2019-10-01')
End10 = ee.Date('2019-12-31')
img = ee.ImageCollection('COPERNICUS/S2')\
    .filterDate(Start10, End10)\
    .filterBounds(PR_polygon)\
    .filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE', 20))\
    .map(maskS2clouds)
composite10 = img.median()

# %%
Map.addLayer(composite10, {'bands':['B8', 'B4', 'B3'], 'min': 0, 'max':0.3}, 'False IR Composite October - December 2019')

# %%
composite_list = [composite0, composite1, composite2, composite3, composite4, composite5, composite6, composite7, composite8, composite9,
                 composite10]

# %%
#Single image ndvi calculation
composite1_ndvi = addNDVI(composite1)
ndvi1 = composite1_ndvi.select(['ndvi'])

# %%
# Exploratory NDVI visualization
# Green = High NDVI value, Yellow = Low NDVI value
visParams_ndvi = {'bands': ['ndvi'], 'min': -0.2, 'max': 0.8, 'palette': 'FFFFFF, CE7E45, DF923D, F1B555, FCD163, 99B718, 74A901, 66A000, 529400,' + \
    '3E8601, 207401, 056201, 004C00, 023B01, 012E01, 011D01, 011301'}
Map.addLayer(ndvi1,visParams_ndvi,'Sentinel-2 NDVI Oct - Dec 2019(sample image)')

# %%
# Adding NDVI bands to all composites
ndvi_dict = {}
for i in range(len(composite_list)):
    ndvi_dict['ndvi %s' %(i)] = composite_list[i]
for k,v in ndvi_dict.items():
    ndvi_dict[k] = addNDVI(v).select(['ndvi'])

# %%
#Calculation for individual farm NDVI mean and SD
#Code showns only the NDVI mean from the first composite (March - June of 2017)
new_geometry_dict ={}
for i in range(len(farm_data)):
    new_geometry_dict['farm %s'%(i)] = ee.Geometry.Point(farms['features'][i]['geometry']['coordinates']).buffer(1000)
    
reducers = ee.Reducer.mean().combine(**{
  'reducer2': ee.Reducer.stdDev(),
  'sharedInputs': True
})

# Use the combined reducer to get the mean and SD of the image.
# We could see the individal farm NDVI has been calculated
# Other sentinel2  Peurto Rico Project Images could be uploaded onto Google Earth Engine and we could try calculating the NDVI value the farms in those images. 
stats_dict ={}
for i in range(len(farm_data)):
    for n in range(len(composite_list)):
        stats_dict['farm %s, composite %s' %(i, n)] = ndvi_dict['ndvi %s'%(n)].reduceRegion(**{
        'reducer': reducers,
        'bestEffort': True,
        'scale': 30,
        'geometry': new_geometry_dict['farm %s'%(i)]
})
for farm in stats_dict.keys():
    print (farm)
    print (stats_dict[farm].getInfo())
# Out:
# farm 0, composite 0
# {'ndvi_mean': 0.6332507061786319, 'ndvi_stdDev': 0.1739024063953939}
# farm 0, composite 1
# {'ndvi_mean': 0.7165135398897369, 'ndvi_stdDev': 0.07219930376415218}
# farm 0, composite 2
# {'ndvi_mean': 0.7061207345285844, 'ndvi_stdDev': 0.08638071503480232}
# farm 0, composite 3
# {'ndvi_mean': 0.7140707999320582, 'ndvi_stdDev': 0.09180558884781748}
# farm 0, composite 4
# {'ndvi_mean': 0.6538867289390089, 'ndvi_stdDev': 0.10589986302941512}
# farm 0, composite 5
# {'ndvi_mean': 0.7005527891924914, 'ndvi_stdDev': 0.08898002282654198}
# farm 0, composite 6
# {'ndvi_mean': 0.7321340374920733, 'ndvi_stdDev': 0.09690954102155408}
# farm 0, composite 7
# {'ndvi_mean': 0.6913389697796902, 'ndvi_stdDev': 0.1055597940932304}
# farm 0, composite 8
# {'ndvi_mean': 0.6977948366848092, 'ndvi_stdDev': 0.10233561979674659}
# farm 0, composite 9
# {'ndvi_mean': 0.7230934880356888, 'ndvi_stdDev': 0.09510156893935746}
# farm 0, composite 10
# {'ndvi_mean': 0.7297479548400456, 'ndvi_stdDev': 0.09479368530918128}
# farm 1, composite 0
# {'ndvi_mean': 0.4811111765692349, 'ndvi_stdDev': 0.20386546659241436}
# farm 1, composite 1
# {'ndvi_mean': 0.6198967108793073, 'ndvi_stdDev': 0.1325386739390898}
# farm 1, composite 2
# {'ndvi_mean': 0.6680448207232086, 'ndvi_stdDev': 0.06999820197282595}
# farm 1, composite 3
# {'ndvi_mean': 0.6817114124369603, 'ndvi_stdDev': 0.08848027261353426}
# farm 1, composite 4
# {'ndvi_mean': 0.5834582991071565, 'ndvi_stdDev': 0.13378118802944478}
# farm 1, composite 5
# {'ndvi_mean': 0.5749811244961964, 'ndvi_stdDev': 0.13069479193467104}
# farm 1, composite 6
# {'ndvi_mean': 0.7143361170219599, 'ndvi_stdDev': 0.07053159736060721}
# farm 1, composite 7
# {'ndvi_mean': 0.688761067591772, 'ndvi_stdDev': 0.07706047737647441}
# farm 1, composite 8
# {'ndvi_mean': 0.6060790547315118, 'ndvi_stdDev': 0.12296491612579426}
# farm 1, composite 9
# {'ndvi_mean': 0.6406439727016413, 'ndvi_stdDev': 0.08573134593859173}
# farm 1, composite 10
# {'ndvi_mean': 0.6981309705597221, 'ndvi_stdDev': 0.07276668604253927}
# farm 2, composite 0
# {'ndvi_mean': None, 'ndvi_stdDev': None}
# farm 2, composite 1
# {'ndvi_mean': 0.5858630558138829, 'ndvi_stdDev': 0.14199167573830523}
# farm 2, composite 2
# {'ndvi_mean': 0.6525347815883972, 'ndvi_stdDev': 0.0795717133014391}
# farm 2, composite 3
# {'ndvi_mean': 0.6884116851041684, 'ndvi_stdDev': 0.0876573284828278}
# farm 2, composite 4
# {'ndvi_mean': 0.5965765598792175, 'ndvi_stdDev': 0.10479006931154455}
# farm 2, composite 5
# {'ndvi_mean': 0.5387749310328431, 'ndvi_stdDev': 0.10931392058452336}
# farm 2, composite 6
# {'ndvi_mean': 0.6899993977376263, 'ndvi_stdDev': 0.09611161646219757}
# farm 2, composite 7
# {'ndvi_mean': 0.5988154796051841, 'ndvi_stdDev': 0.125522403893541}
# farm 2, composite 8
# {'ndvi_mean': 0.6222495576776688, 'ndvi_stdDev': 0.09998454145919602}
# farm 2, composite 9
# {'ndvi_mean': 0.6429703390747487, 'ndvi_stdDev': 0.08573288172068756}
# farm 2, composite 10
# {'ndvi_mean': 0.6364471889578426, 'ndvi_stdDev': 0.11546534142912075}
# farm 3, composite 0
# {'ndvi_mean': None, 'ndvi_stdDev': None}
# farm 3, composite 1
# {'ndvi_mean': 0.6329701578212906, 'ndvi_stdDev': 0.13740242039293488}
# farm 3, composite 2
# {'ndvi_mean': 0.7123316422278013, 'ndvi_stdDev': 0.05968657308807382}
# farm 3, composite 3
# {'ndvi_mean': 0.7130522491327267, 'ndvi_stdDev': 0.07016491121087629}
# farm 3, composite 4
# {'ndvi_mean': 0.451850084208698, 'ndvi_stdDev': 0.16114928699174808}
# farm 3, composite 5
# {'ndvi_mean': 0.6657660950975863, 'ndvi_stdDev': 0.0780378081926615}
# farm 3, composite 6
# {'ndvi_mean': 0.7620907947336127, 'ndvi_stdDev': 0.06314003006133102}
# farm 3, composite 7
# {'ndvi_mean': 0.7185954111710094, 'ndvi_stdDev': 0.07033167975730871}
# farm 3, composite 8
# {'ndvi_mean': 0.6569674023921327, 'ndvi_stdDev': 0.13050770984343815}
# farm 3, composite 9
# {'ndvi_mean': 0.7571938202530896, 'ndvi_stdDev': 0.04937986212847863}
# farm 3, composite 10
# {'ndvi_mean': 0.7553520160477489, 'ndvi_stdDev': 0.06781880111845706}
# farm 4, composite 0
# {'ndvi_mean': 0.7463863540115185, 'ndvi_stdDev': 0.07249544284000714}
# farm 4, composite 1
# {'ndvi_mean': 0.7328141582623316, 'ndvi_stdDev': 0.056620193786274614}
# farm 4, composite 2
# {'ndvi_mean': 0.7197873294770235, 'ndvi_stdDev': 0.06584488891224999}
# farm 4, composite 3
# {'ndvi_mean': 0.7140564657046642, 'ndvi_stdDev': 0.07970043834433586}
# farm 4, composite 4
# {'ndvi_mean': 0.6715747854109562, 'ndvi_stdDev': 0.07189320546839767}
# farm 4, composite 5
# {'ndvi_mean': 0.6995657274932906, 'ndvi_stdDev': 0.056567936583565695}
# farm 4, composite 6
# {'ndvi_mean': 0.7574265218461353, 'ndvi_stdDev': 0.0634682753782219}
# farm 4, composite 7
# {'ndvi_mean': 0.7119814547863204, 'ndvi_stdDev': 0.07967435046529574}
# farm 4, composite 8
# {'ndvi_mean': 0.6992010312010545, 'ndvi_stdDev': 0.08393709843226815}
# farm 4, composite 9
# {'ndvi_mean': 0.7126676739778702, 'ndvi_stdDev': 0.059206754752941945}
# farm 4, composite 10
# {'ndvi_mean': 0.7308531299509018, 'ndvi_stdDev': 0.06429944389559293}
# farm 5, composite 0
# {'ndvi_mean': 0.4256891079822802, 'ndvi_stdDev': 0.1979548269923872}
# farm 5, composite 1
# {'ndvi_mean': 0.6356419334297789, 'ndvi_stdDev': 0.11517372922379901}
# farm 5, composite 2
# {'ndvi_mean': 0.6861042915372733, 'ndvi_stdDev': 0.06706533197548181}
# farm 5, composite 3
# {'ndvi_mean': 0.7007941448649581, 'ndvi_stdDev': 0.09117932703477992}
# farm 5, composite 4
# {'ndvi_mean': 0.6109987357472138, 'ndvi_stdDev': 0.07986259049486427}
# farm 5, composite 5
# {'ndvi_mean': 0.6484054907512555, 'ndvi_stdDev': 0.08409460961751936}
# farm 5, composite 6
# {'ndvi_mean': 0.7433407694763469, 'ndvi_stdDev': 0.06864843265244634}
# farm 5, composite 7
# {'ndvi_mean': 0.6518413346947862, 'ndvi_stdDev': 0.12331080025588635}
# farm 5, composite 8
# {'ndvi_mean': 0.6410123676726841, 'ndvi_stdDev': 0.1085294990359759}
# farm 5, composite 9
# {'ndvi_mean': 0.6797913248957467, 'ndvi_stdDev': 0.0688835590356157}
# farm 5, composite 10
# {'ndvi_mean': 0.7014042104868585, 'ndvi_stdDev': 0.09020075684213989}
# farm 6, composite 0
# {'ndvi_mean': 0.5758554904571255, 'ndvi_stdDev': 0.2240005584788342}
# farm 6, composite 1
# {'ndvi_mean': 0.6340262549785869, 'ndvi_stdDev': 0.12512740787346768}
# farm 6, composite 2
# {'ndvi_mean': 0.670378681023076, 'ndvi_stdDev': 0.07084938324850432}
# farm 6, composite 3
# {'ndvi_mean': 0.704285646023333, 'ndvi_stdDev': 0.08103743814202603}
# farm 6, composite 4
# {'ndvi_mean': 0.5358032064640055, 'ndvi_stdDev': 0.13430491673479386}
# farm 6, composite 5
# {'ndvi_mean': 0.5707498143600677, 'ndvi_stdDev': 0.12670058557827654}
# farm 6, composite 6
# {'ndvi_mean': 0.722774371370143, 'ndvi_stdDev': 0.07537616602737669}
# farm 6, composite 7
# {'ndvi_mean': 0.6903389795622009, 'ndvi_stdDev': 0.08069819315772081}
# farm 6, composite 8
# {'ndvi_mean': 0.6552002728960257, 'ndvi_stdDev': 0.08814676368764614}
# farm 6, composite 9
# {'ndvi_mean': 0.6488043223844175, 'ndvi_stdDev': 0.0876032412255688}
# farm 6, composite 10
# {'ndvi_mean': 0.7062373141110418, 'ndvi_stdDev': 0.07224030697265192}
# farm 7, composite 0
# {'ndvi_mean': 0.746494257212013, 'ndvi_stdDev': 0.08761443657465974}
# farm 7, composite 1
# {'ndvi_mean': 0.7539468840750755, 'ndvi_stdDev': 0.05414107825453165}
# farm 7, composite 2
# {'ndvi_mean': 0.7346474039245705, 'ndvi_stdDev': 0.07099259885973862}
# farm 7, composite 3
# {'ndvi_mean': 0.7415601874513166, 'ndvi_stdDev': 0.08259534081418923}
# farm 7, composite 4
# {'ndvi_mean': 0.5884713518945786, 'ndvi_stdDev': 0.09382902933340859}
# farm 7, composite 5
# {'ndvi_mean': 0.68835932438617, 'ndvi_stdDev': 0.07074743055959275}
# farm 7, composite 6
# {'ndvi_mean': 0.7608795162637343, 'ndvi_stdDev': 0.07186073810064202}
# farm 7, composite 7
# {'ndvi_mean': 0.7061296499197249, 'ndvi_stdDev': 0.10683065964008456}
# farm 7, composite 8
# {'ndvi_mean': 0.735981154761037, 'ndvi_stdDev': 0.09090948367939394}
# farm 7, composite 9
# {'ndvi_mean': 0.7310396262906932, 'ndvi_stdDev': 0.06217288453016911}
# farm 7, composite 10
# {'ndvi_mean': 0.7492130253431065, 'ndvi_stdDev': 0.07029867128868111}
# farm 8, composite 0
# {'ndvi_mean': 0.7296597303820592, 'ndvi_stdDev': 0.1066381774882295}
# farm 8, composite 1
# {'ndvi_mean': 0.7574126898627558, 'ndvi_stdDev': 0.05499330633012466}
# farm 8, composite 2
# {'ndvi_mean': 0.7331201702840773, 'ndvi_stdDev': 0.07287803938901306}
# farm 8, composite 3
# {'ndvi_mean': 0.7349646950883162, 'ndvi_stdDev': 0.0832072334314334}
# farm 8, composite 4
# {'ndvi_mean': 0.6302325616716352, 'ndvi_stdDev': 0.09045450893362612}
# farm 8, composite 5
# {'ndvi_mean': 0.7033221045983815, 'ndvi_stdDev': 0.061445630543373125}
# farm 8, composite 6
# {'ndvi_mean': 0.7589753392837264, 'ndvi_stdDev': 0.07428681605713544}
# farm 8, composite 7
# {'ndvi_mean': 0.7044082035890231, 'ndvi_stdDev': 0.10597834444152719}
# farm 8, composite 8
# {'ndvi_mean': 0.7386336997602744, 'ndvi_stdDev': 0.09182127726275272}
# farm 8, composite 9
# {'ndvi_mean': 0.7290662736336875, 'ndvi_stdDev': 0.06358868950356528}
# farm 8, composite 10
# {'ndvi_mean': 0.7481293013475342, 'ndvi_stdDev': 0.07420333419799319}
# farm 9, composite 0
# {'ndvi_mean': 0.492859529556065, 'ndvi_stdDev': 0.1248835873366531}
# farm 9, composite 1
# {'ndvi_mean': 0.6994091284509374, 'ndvi_stdDev': 0.10064713430231888}
# farm 9, composite 2
# {'ndvi_mean': 0.7176068314144126, 'ndvi_stdDev': 0.06138061806303244}
# farm 9, composite 3
# {'ndvi_mean': 0.7115519065472053, 'ndvi_stdDev': 0.07508165979697248}
# farm 9, composite 4
# {'ndvi_mean': 0.6082014263799155, 'ndvi_stdDev': 0.16178133326773958}
# farm 9, composite 5
# {'ndvi_mean': 0.6682542328188004, 'ndvi_stdDev': 0.06740363455761417}
# farm 9, composite 6
# {'ndvi_mean': 0.766782187572807, 'ndvi_stdDev': 0.06198936715527853}
# farm 9, composite 7
# {'ndvi_mean': 0.7303402900929258, 'ndvi_stdDev': 0.07901504868069247}
# farm 9, composite 8
# {'ndvi_mean': 0.6780715416952189, 'ndvi_stdDev': 0.0900192582057289}
# farm 9, composite 9
# {'ndvi_mean': 0.7454500933809006, 'ndvi_stdDev': 0.06078356782655862}
# farm 9, composite 10
# {'ndvi_mean': 0.7604451225922093, 'ndvi_stdDev': 0.05661567100327696}
# farm 10, composite 0
# {'ndvi_mean': 0.5757018458392609, 'ndvi_stdDev': 0.03244075874564167}
# farm 10, composite 1
# {'ndvi_mean': 0.6446425087569346, 'ndvi_stdDev': 0.09983969854569533}
# farm 10, composite 2
# {'ndvi_mean': 0.6320597966391454, 'ndvi_stdDev': 0.09728425723820493}
# farm 10, composite 3
# {'ndvi_mean': 0.6368372287607529, 'ndvi_stdDev': 0.11956484224670226}
# farm 10, composite 4
# {'ndvi_mean': 0.584150064244327, 'ndvi_stdDev': 0.1031890621416604}
# farm 10, composite 5
# {'ndvi_mean': 0.5188745282599605, 'ndvi_stdDev': 0.1206482236624221}
# farm 10, composite 6
# {'ndvi_mean': 0.6823913292371663, 'ndvi_stdDev': 0.10290134516264689}
# farm 10, composite 7
# {'ndvi_mean': 0.5823200330289807, 'ndvi_stdDev': 0.1172880818490417}
# farm 10, composite 8
# {'ndvi_mean': 0.618155506838337, 'ndvi_stdDev': 0.09868477370790729}
# farm 10, composite 9
# {'ndvi_mean': 0.6459598912631201, 'ndvi_stdDev': 0.0920332426903627}
# farm 10, composite 10
# {'ndvi_mean': 0.6825766239096976, 'ndvi_stdDev': 0.10665683011572231}
# farm 11, composite 0
# {'ndvi_mean': 0.40194172984934695, 'ndvi_stdDev': 0.17086469144831107}
# farm 11, composite 1
# {'ndvi_mean': 0.6790587616759037, 'ndvi_stdDev': 0.10606794561983177}
# farm 11, composite 2
# {'ndvi_mean': 0.7217377825962255, 'ndvi_stdDev': 0.06207358413590007}
# farm 11, composite 3
# {'ndvi_mean': 0.6759405719169722, 'ndvi_stdDev': 0.09066241315760827}
# farm 11, composite 4
# {'ndvi_mean': 0.5942522955602032, 'ndvi_stdDev': 0.1539545693046262}
# farm 11, composite 5
# {'ndvi_mean': 0.6550410168201795, 'ndvi_stdDev': 0.06896540735530476}
# farm 11, composite 6
# {'ndvi_mean': 0.7706438380624869, 'ndvi_stdDev': 0.059408398818442655}
# farm 11, composite 7
# {'ndvi_mean': 0.7265692524032573, 'ndvi_stdDev': 0.07663770302535049}
# farm 11, composite 8
# {'ndvi_mean': 0.6714207488107423, 'ndvi_stdDev': 0.10535176016926756}
# farm 11, composite 9
# {'ndvi_mean': 0.7422668905916515, 'ndvi_stdDev': 0.060769707180731054}
# farm 11, composite 10
# {'ndvi_mean': 0.7527326280403723, 'ndvi_stdDev': 0.05592074308885256}
# farm 12, composite 0
# {'ndvi_mean': 0.6253767284132546, 'ndvi_stdDev': 0.16713176814424946}
# farm 12, composite 1
# {'ndvi_mean': 0.713891240989554, 'ndvi_stdDev': 0.05800413028578854}
# farm 12, composite 2
# {'ndvi_mean': 0.70658366922816, 'ndvi_stdDev': 0.07416127695801238}
# farm 12, composite 3
# {'ndvi_mean': 0.7185064101367908, 'ndvi_stdDev': 0.07770123844985247}
# farm 12, composite 4
# {'ndvi_mean': 0.6767321810255333, 'ndvi_stdDev': 0.08894271947326046}
# farm 12, composite 5
# {'ndvi_mean': 0.6915568933865519, 'ndvi_stdDev': 0.09700830781379656}
# farm 12, composite 6
# {'ndvi_mean': 0.7498922475957467, 'ndvi_stdDev': 0.07791567175324263}
# farm 12, composite 7
# {'ndvi_mean': 0.7116654286676088, 'ndvi_stdDev': 0.08523202543331458}
# farm 12, composite 8
# {'ndvi_mean': 0.691381643194813, 'ndvi_stdDev': 0.09101918971816315}
# farm 12, composite 9
# {'ndvi_mean': 0.7269234622892395, 'ndvi_stdDev': 0.07714719887201106}
# farm 12, composite 10
# {'ndvi_mean': 0.743741356252529, 'ndvi_stdDev': 0.07513426243840816}
# farm 13, composite 0
# {'ndvi_mean': 0.379043210920737, 'ndvi_stdDev': 0.16482919585874464}
# farm 13, composite 1
# {'ndvi_mean': 0.7393435719649489, 'ndvi_stdDev': 0.06715538777524423}
# farm 13, composite 2
# {'ndvi_mean': 0.7240034523966986, 'ndvi_stdDev': 0.08002185994388067}
# farm 13, composite 3
# {'ndvi_mean': 0.7232698436239249, 'ndvi_stdDev': 0.08915845477911202}
# farm 13, composite 4
# {'ndvi_mean': 0.7062422324701333, 'ndvi_stdDev': 0.08150217345718543}
# farm 13, composite 5
# {'ndvi_mean': 0.7232024539055104, 'ndvi_stdDev': 0.08215070180664205}
# farm 13, composite 6
# {'ndvi_mean': 0.7551201996166057, 'ndvi_stdDev': 0.08133248175223316}
# farm 13, composite 7
# {'ndvi_mean': 0.6899995681894622, 'ndvi_stdDev': 0.09949431053011733}
# farm 13, composite 8
# {'ndvi_mean': 0.707749296860197, 'ndvi_stdDev': 0.0967750046984589}
# farm 13, composite 9
# {'ndvi_mean': 0.7380836262532784, 'ndvi_stdDev': 0.07515650282276885}
# farm 13, composite 10
# {'ndvi_mean': 0.7561126821300722, 'ndvi_stdDev': 0.07467567338773293}
# farm 14, composite 0
# {'ndvi_mean': 0.489886757880628, 'ndvi_stdDev': 0.197832710235732}
# farm 14, composite 1
# {'ndvi_mean': 0.7126508774142521, 'ndvi_stdDev': 0.08611477001011594}
# farm 14, composite 2
# {'ndvi_mean': 0.6965798873852785, 'ndvi_stdDev': 0.0965830995455301}
# farm 14, composite 3
# {'ndvi_mean': 0.7003099514824844, 'ndvi_stdDev': 0.10823876207058254}
# farm 14, composite 4
# {'ndvi_mean': 0.6831673786285741, 'ndvi_stdDev': 0.09957223260272975}
# farm 14, composite 5
# {'ndvi_mean': 0.6976556547873977, 'ndvi_stdDev': 0.10867395627285645}
# farm 14, composite 6
# {'ndvi_mean': 0.7283599304884495, 'ndvi_stdDev': 0.10397198831499821}
# farm 14, composite 7
# {'ndvi_mean': 0.6748816133881281, 'ndvi_stdDev': 0.11363192126967016}
# farm 14, composite 8
# {'ndvi_mean': 0.691066723075743, 'ndvi_stdDev': 0.11501044556634672}
# farm 14, composite 9
# {'ndvi_mean': 0.7095761714968496, 'ndvi_stdDev': 0.0976106745035941}
# farm 14, composite 10
# {'ndvi_mean': 0.7326546644048079, 'ndvi_stdDev': 0.09905416575801367}
# farm 15, composite 0
# {'ndvi_mean': 0.7173691453667923, 'ndvi_stdDev': 0.11099047912407181}
# farm 15, composite 1
# {'ndvi_mean': 0.6906801072157793, 'ndvi_stdDev': 0.06878979395814525}
# farm 15, composite 2
# {'ndvi_mean': 0.693739120830372, 'ndvi_stdDev': 0.07233719314585633}
# farm 15, composite 3
# {'ndvi_mean': 0.6941033070401403, 'ndvi_stdDev': 0.08266953535429485}
# farm 15, composite 4
# {'ndvi_mean': 0.6160324116672078, 'ndvi_stdDev': 0.12899864842906889}
# farm 15, composite 5
# {'ndvi_mean': 0.6969894090367066, 'ndvi_stdDev': 0.0770229350745216}
# farm 15, composite 6
# {'ndvi_mean': 0.7286610747916109, 'ndvi_stdDev': 0.08008398597461593}
# farm 15, composite 7
# {'ndvi_mean': 0.6677343002047817, 'ndvi_stdDev': 0.0994376067272437}
# farm 15, composite 8
# {'ndvi_mean': 0.6891887487429008, 'ndvi_stdDev': 0.11195490136476108}
# farm 15, composite 9
# {'ndvi_mean': 0.712617953818208, 'ndvi_stdDev': 0.09003934033566555}
# farm 15, composite 10
# {'ndvi_mean': 0.7215653846600332, 'ndvi_stdDev': 0.08093736499831478}
# farm 16, composite 0
# {'ndvi_mean': 0.6689533788831199, 'ndvi_stdDev': 0.18083723924704817}
# farm 16, composite 1
# {'ndvi_mean': 0.6433309973775706, 'ndvi_stdDev': 0.10363396301040524}
# farm 16, composite 2
# {'ndvi_mean': 0.6716667028147855, 'ndvi_stdDev': 0.07349697814707133}
# farm 16, composite 3
# {'ndvi_mean': 0.7063008629304808, 'ndvi_stdDev': 0.08262850330721914}
# farm 16, composite 4
# {'ndvi_mean': 0.533090497611671, 'ndvi_stdDev': 0.13350980429295417}
# farm 16, composite 5
# {'ndvi_mean': 0.5797098621046449, 'ndvi_stdDev': 0.11651981939305503}
# farm 16, composite 6
# {'ndvi_mean': 0.7201615261527021, 'ndvi_stdDev': 0.07966249209483409}
# farm 16, composite 7
# {'ndvi_mean': 0.6765185150629058, 'ndvi_stdDev': 0.08563563807719322}
# farm 16, composite 8
# {'ndvi_mean': 0.6555110027398646, 'ndvi_stdDev': 0.08446639717986765}
# farm 16, composite 9
# {'ndvi_mean': 0.6382254492876952, 'ndvi_stdDev': 0.08418085714810054}
# farm 16, composite 10
# {'ndvi_mean': 0.7007297397561706, 'ndvi_stdDev': 0.0735799248726129}
# farm 17, composite 0
# {'ndvi_mean': 0.5643188199500585, 'ndvi_stdDev': 0.20744845542257806}
# farm 17, composite 1
# {'ndvi_mean': 0.6632876424823413, 'ndvi_stdDev': 0.1084540147616758}
# farm 17, composite 2
# {'ndvi_mean': 0.6375845117695742, 'ndvi_stdDev': 0.10533135408081931}
# farm 17, composite 3
# {'ndvi_mean': 0.6498252042813905, 'ndvi_stdDev': 0.12264454970813957}
# farm 17, composite 4
# {'ndvi_mean': 0.622063443542215, 'ndvi_stdDev': 0.11267895125485096}
# farm 17, composite 5
# {'ndvi_mean': 0.6032211662977361, 'ndvi_stdDev': 0.10920690819092138}
# farm 17, composite 6
# {'ndvi_mean': 0.6654287171133789, 'ndvi_stdDev': 0.11771575348759143}
# farm 17, composite 7
# {'ndvi_mean': 0.633072599855569, 'ndvi_stdDev': 0.11546221159231947}
# farm 17, composite 8
# {'ndvi_mean': 0.591003326057833, 'ndvi_stdDev': 0.11786387589726915}
# farm 17, composite 9
# {'ndvi_mean': 0.6571362870114809, 'ndvi_stdDev': 0.10104878347223505}
# farm 17, composite 10
# {'ndvi_mean': 0.6776197108906953, 'ndvi_stdDev': 0.10792951919308205}
# farm 18, composite 0
# {'ndvi_mean': 0.5928494961800177, 'ndvi_stdDev': 0.17184621703704495}
# farm 18, composite 1
# {'ndvi_mean': 0.6683863087268077, 'ndvi_stdDev': 0.10748193853322592}
# farm 18, composite 2
# {'ndvi_mean': 0.6399434678216328, 'ndvi_stdDev': 0.11524928891539464}
# farm 18, composite 3
# {'ndvi_mean': 0.6441043483555842, 'ndvi_stdDev': 0.13382367907280918}
# farm 18, composite 4
# {'ndvi_mean': 0.6253462327763515, 'ndvi_stdDev': 0.1204340364699813}
# farm 18, composite 5
# {'ndvi_mean': 0.6072297013021466, 'ndvi_stdDev': 0.11534924952597193}
# farm 18, composite 6
# {'ndvi_mean': 0.6516576795654186, 'ndvi_stdDev': 0.12779306191895556}
# farm 18, composite 7
# {'ndvi_mean': 0.6433167319624066, 'ndvi_stdDev': 0.12050175204955489}
# farm 18, composite 8
# {'ndvi_mean': 0.5938941529353047, 'ndvi_stdDev': 0.11889582609876907}
# farm 18, composite 9
# {'ndvi_mean': 0.6563356077556544, 'ndvi_stdDev': 0.10948999981066486}
# farm 18, composite 10
# {'ndvi_mean': 0.6768062570351836, 'ndvi_stdDev': 0.11861022011871236}
# farm 19, composite 0
# {'ndvi_mean': 0.6733299362026142, 'ndvi_stdDev': 0.12994900186133762}
# farm 19, composite 1
# {'ndvi_mean': 0.6989412541145514, 'ndvi_stdDev': 0.07127356546703899}
# farm 19, composite 2
# {'ndvi_mean': 0.6849094310117514, 'ndvi_stdDev': 0.07569702568062261}
# farm 19, composite 3
# {'ndvi_mean': 0.680813161919165, 'ndvi_stdDev': 0.09587792648592015}
# farm 19, composite 4
# {'ndvi_mean': 0.6650149056480126, 'ndvi_stdDev': 0.0884057151616362}
# farm 19, composite 5
# {'ndvi_mean': 0.6904514934847062, 'ndvi_stdDev': 0.08839624852421513}
# farm 19, composite 6
# {'ndvi_mean': 0.7319808598257432, 'ndvi_stdDev': 0.08021778923828543}
# farm 19, composite 7
# {'ndvi_mean': 0.6854351777218215, 'ndvi_stdDev': 0.09722836052719164}
# farm 19, composite 8
# {'ndvi_mean': 0.6716849362947803, 'ndvi_stdDev': 0.09575174198253787}
# farm 19, composite 9
# {'ndvi_mean': 0.69084632625208, 'ndvi_stdDev': 0.0807732347008243}
# farm 19, composite 10
# {'ndvi_mean': 0.7124003955213254, 'ndvi_stdDev': 0.07990223047029997}
# farm 20, composite 0
# {'ndvi_mean': 0.3706864078993955, 'ndvi_stdDev': 0.30081334427964196}
# farm 20, composite 1
# {'ndvi_mean': 0.529001486789452, 'ndvi_stdDev': 0.2322507992475056}
# farm 20, composite 2
# {'ndvi_mean': 0.49698688892187803, 'ndvi_stdDev': 0.309536688364939}
# farm 20, composite 3
# {'ndvi_mean': 0.49259556341987687, 'ndvi_stdDev': 0.3248943268227768}
# farm 20, composite 4
# {'ndvi_mean': 0.4545184912839558, 'ndvi_stdDev': 0.23309267201007927}
# farm 20, composite 5
# {'ndvi_mean': 0.45796524817542644, 'ndvi_stdDev': 0.22834871318758845}
# farm 20, composite 6
# {'ndvi_mean': 0.5373954815849729, 'ndvi_stdDev': 0.33392622022802004}
# farm 20, composite 7
# {'ndvi_mean': 0.4565575811656781, 'ndvi_stdDev': 0.29211226956401387}
# farm 20, composite 8
# {'ndvi_mean': 0.4723187072299898, 'ndvi_stdDev': 0.25400618819960136}
# farm 20, composite 9
# {'ndvi_mean': 0.5451083458319185, 'ndvi_stdDev': 0.23197317243908508}
# farm 20, composite 10
# {'ndvi_mean': 0.5335046587968683, 'ndvi_stdDev': 0.30782263728556836}
# farm 21, composite 0
# {'ndvi_mean': 0.4003551612615076, 'ndvi_stdDev': 0.19797557368822682}
# farm 21, composite 1
# {'ndvi_mean': 0.6469451328811845, 'ndvi_stdDev': 0.10758086379654594}
# farm 21, composite 2
# {'ndvi_mean': 0.6919163389293941, 'ndvi_stdDev': 0.08164090198644067}
# farm 21, composite 3
# {'ndvi_mean': 0.6987919778993729, 'ndvi_stdDev': 0.10312469884997114}
# farm 21, composite 4
# {'ndvi_mean': 0.5990214665428065, 'ndvi_stdDev': 0.12472436669907443}
# farm 21, composite 5
# {'ndvi_mean': 0.6341049889641537, 'ndvi_stdDev': 0.11752729117376377}
# farm 21, composite 6
# {'ndvi_mean': 0.7321964558861438, 'ndvi_stdDev': 0.08082700917531237}
# farm 21, composite 7
# {'ndvi_mean': 0.6796166277051184, 'ndvi_stdDev': 0.09668505770391952}
# farm 21, composite 8
# {'ndvi_mean': 0.6799466391743881, 'ndvi_stdDev': 0.09974646437311949}
# farm 21, composite 9
# {'ndvi_mean': 0.6782566533999791, 'ndvi_stdDev': 0.08624224566535181}
# farm 21, composite 10
# {'ndvi_mean': 0.7200885521561625, 'ndvi_stdDev': 0.07541541005089267}
# farm 22, composite 0
# {'ndvi_mean': 0.5696194047042773, 'ndvi_stdDev': 0.19828697258598146}
# farm 22, composite 1
# {'ndvi_mean': 0.6636676667599508, 'ndvi_stdDev': 0.1338440899835161}
# farm 22, composite 2
# {'ndvi_mean': 0.6707098148077627, 'ndvi_stdDev': 0.06585076036836743}
# farm 22, composite 3
# {'ndvi_mean': 0.6862918952793338, 'ndvi_stdDev': 0.08743766922556309}
# farm 22, composite 4
# {'ndvi_mean': 0.5638785284443222, 'ndvi_stdDev': 0.12585642486231358}
# farm 22, composite 5
# {'ndvi_mean': 0.5596338752042112, 'ndvi_stdDev': 0.11828425127224076}
# farm 22, composite 6
# {'ndvi_mean': 0.7166286827289297, 'ndvi_stdDev': 0.07318386106683801}
# farm 22, composite 7
# {'ndvi_mean': 0.6594484055272201, 'ndvi_stdDev': 0.09097805840167711}
# farm 22, composite 8
# {'ndvi_mean': 0.6334630891233384, 'ndvi_stdDev': 0.09959401085148857}
# farm 22, composite 9
# {'ndvi_mean': 0.6693768200005714, 'ndvi_stdDev': 0.08648357193656299}
# farm 22, composite 10
# {'ndvi_mean': 0.5959115545504922, 'ndvi_stdDev': 0.1448424861042185}
# farm 23, composite 0
# {'ndvi_mean': 0.6698290920070359, 'ndvi_stdDev': 0.1676397753254274}
# farm 23, composite 1
# {'ndvi_mean': 0.7133623762149471, 'ndvi_stdDev': 0.08925700371137357}
# farm 23, composite 2
# {'ndvi_mean': 0.6736707634572807, 'ndvi_stdDev': 0.08667511599965633}
# farm 23, composite 3
# {'ndvi_mean': 0.6908540229490017, 'ndvi_stdDev': 0.09990008979600715}
# farm 23, composite 4
# {'ndvi_mean': 0.6527098182623313, 'ndvi_stdDev': 0.0948318048741004}
# farm 23, composite 5
# {'ndvi_mean': 0.5602573559071888, 'ndvi_stdDev': 0.13742128932153294}
# farm 23, composite 6
# {'ndvi_mean': 0.7218365337656861, 'ndvi_stdDev': 0.08885989093826202}
# farm 23, composite 7
# {'ndvi_mean': 0.6945825960176919, 'ndvi_stdDev': 0.10230221843620217}
# farm 23, composite 8
# {'ndvi_mean': 0.6912331353143305, 'ndvi_stdDev': 0.09677025702784366}
# farm 23, composite 9
# {'ndvi_mean': 0.6913040196194946, 'ndvi_stdDev': 0.08004187597995134}
# farm 23, composite 10
# {'ndvi_mean': 0.726097383958879, 'ndvi_stdDev': 0.07974078976702598}
# farm 24, composite 0
# {'ndvi_mean': 0.6954147886041389, 'ndvi_stdDev': 0.1492464118395134}
# farm 24, composite 1
# {'ndvi_mean': 0.704599690243792, 'ndvi_stdDev': 0.09731776623282964}
# farm 24, composite 2
# {'ndvi_mean': 0.6780555733176254, 'ndvi_stdDev': 0.09405599585181433}
# farm 24, composite 3
# {'ndvi_mean': 0.6919894513866178, 'ndvi_stdDev': 0.10709613188096406}
# farm 24, composite 4
# {'ndvi_mean': 0.6485374874344214, 'ndvi_stdDev': 0.09885182423522212}
# farm 24, composite 5
# {'ndvi_mean': 0.6108021083609182, 'ndvi_stdDev': 0.11579324812737922}
# farm 24, composite 6
# {'ndvi_mean': 0.7242197979190597, 'ndvi_stdDev': 0.09569840893681009}
# farm 24, composite 7
# {'ndvi_mean': 0.6890109997203198, 'ndvi_stdDev': 0.11192416211435201}
# farm 24, composite 8
# {'ndvi_mean': 0.6712061862384177, 'ndvi_stdDev': 0.10843520515377053}
# farm 24, composite 9
# {'ndvi_mean': 0.6799302179914558, 'ndvi_stdDev': 0.08628301256654541}
# farm 24, composite 10
# {'ndvi_mean': 0.7253943216782347, 'ndvi_stdDev': 0.08949181739886047}

# %%
with open('dict.csv', 'w', newline="") as csv_file:  
    writer = csv.writer(csv_file)
    for key, value in stats_dict.items():
       writer.writerow([key, value.getInfo()])

# %%
#This was an attempt to export the images from Google Earth Engine
#I have tried many ways such as save to drive or save to computer but they all show up corrupted.
#The code seems correct - it might be a python API problem. 
task_config = {
    'folder': 'gee', # output Google Drive folder
    'region': PR_polygon,     # roi 
    'scale': 100,       # image resolution
    'crs': 'EPSG:4326',
    'maxPixels': 1.0E13,
    'fileFormat': 'GeoTIFF'
    }
image = composite9
description = 'Composite 9'

# Export image to Google Drive
task = ee.batch.Export.image.toDrive(image, description, **task_config)
print(task)
task.start()
print("Exporting {}".format(description))
# Out:
# <Task EXPORT_IMAGE: Composite 9 (UNSUBMITTED)>
# Exporting Composite 9

# %% [markdown]
# #Future Work
# The next step is to create an organized chart to consolidate all of the ndvi values for each farm. These data be plotted to show how the NDVI values have changed from 2017 until now. The composite images also needs to be properly exported. Right now, the exported images shows up corrupted and are unusable. More work needs to be done to either investigate what is wrong with  image export in Google Earth Engine Python API or the python script could be converted to Javascript and we could run it through the Javascript API. We could also put togeter as a timelapse for visualization. Further comparison with data before 2017 could give us a better understanding of the changes in the landcover. These data could then be used as reference points for further data fusion work.
